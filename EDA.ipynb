# %%
import pandas as pd
import os
import json
import re
from tqdm import tqdm, trange
import logging

from pprint import PrettyPrinter
from collections import defaultdict

# %% [markdown]
# ## Steps to reproduction
# 1. Download all 5 GB of data, or clone the repository at https://github.com/gilpasternak35/SongRecommender.git
#
#
# 2. **If Downloaded**:\
#     a. keep only first 81,000 playlists
#     b. Place these in a directory called data, one step below current root
#
#
# 3. Run this notebook from repository root

# %%
# Listing directory
files = os.listdir("./data")

# Regular expression for desired filenames
desired_filename = re.compile("mpd.*")

# Pretty printer instantiation
pp = PrettyPrinter(width=25)

# %%
def dataloader_pipeline(file_list: list) -> list:
    """
    Pipeline for loading in data
    
    @param file_list: A list of files to load in
    @returns data: A list of playlists from these files
    """
    # Resulting data (hopefully to be stored in list)
    data = []
    
    # Traversing through available datafiles
    print("Starting Dataloading...")
    for file in tqdm(file_list):
        
        # Ensuring filename valid
        if desired_filename.match(file):
            
            # Opening and preprocessing
            with open("./data/" + file, 'r') as file_reader:
                data += json.load(file_reader)["playlists"]
    
    print("Finished Dataloading...")
   
    return data

# %%
def build_relevant_ds(data: list) -> (list, dict, dict, dict):
    """
    Preprocesses data, simultaneously building relevant data structures
    
    @param data - a data list of playlist dictionaries to preprocess
    @returns a list of tracks per user, users per track, watered down data list
    """
    
    def process_uri(uri:str):
        """URI Processing method"""
        return uri.split(":")[2]
        
    
    print("Preprocessing started...")
    tracks_per_user, users_per_track, artists_per_user  = defaultdict(list), defaultdict(list), defaultdict(list)
    
    # Traversing through data and preprocessing
    for playlist in data:       
        user = playlist['pid']
        for track in playlist['tracks']:
            # obtaining necessary data
            track, artist, album = track['track_name'], track['artist_name'], track['album_name']
            
            # Appending data to data structures
            tracks_per_user[user].append(track)
            users_per_track[track].append(user)
            artists_per_user[user].append(artist)
            
    return tracks_per_user, users_per_track, artists_per_user

# %%
# Loading in data
data = dataloader_pipeline(files)
# Out:
# Starting Dataloading...
# 100%|███████████████████████████████████████████| 81/81 [00:17<00:00,  4.52it/s]
# Finished Dataloading...

# %% [markdown]
# ## Our Data:

# %%
pp.pprint(data[2])
# Out:
# {'collaborative': 'false',
#  'duration_ms': 15021695,
#  'modified_at': 1505433600,
#  'name': 'offline ',
#  'num_albums': 48,
#  'num_artists': 45,
#  'num_edits': 16,
#  'num_followers': 1,
#  'num_tracks': 63,
#  'pid': 7002,
#  'tracks': [{'album_name': 'Greatest '
#                            'Hits '
#                            '- '
#                            '18 '
#                            'Kids',
#              'album_uri': 'spotify:album:0xBQEVKKlFKaetqike1qXK',
#              'artist_name': 'Keith '
#                             'Urban',
#              'artist_uri': 'spotify:artist:0u2FHSq3ln94y5Q57xazwf',
#              'duration_ms': 231293,
#              'pos': 0,
#              'track_name': "You'll "
#                            'Think '
#                            'Of '
#                            'Me',
#              'track_uri': 'spotify:track:0lZxd99ZIjA0zUdQAY3FXr'},
#             {'album_name': 'Me '
#                            'And '
#                            'My '
#                            'Gang',
#              'album_uri': 'spotify:album:0SAwvmZ1uhBrC6sOZxp6jW',
#              'artist_name': 'Rascal '
#                             'Flatts',
#              'artist_uri': 'spotify:artist:0a1gHP0HAqALbEyxaD5Ngn',
#              'duration_ms': 214106,
#              'pos': 1,
#              'track_name': 'What '
#                            'Hurts '
#                            'The '
#                            'Most',
#              'track_uri': 'spotify:track:6U5pgPq1bsJ6UBeakd4mfQ'},
#             {'album_name': 'ZABA',
#              'album_uri': 'spotify:album:2ipSXAsBLmvEeVKKbRAL7i',
#              'artist_name': 'Glass '
#                             'Animals',
#              'artist_uri': 'spotify:artist:4yvcSjfu4PC0CYQyLy4wSq',
#              'duration_ms': 289306,
#              'pos': 2,
#              'track_name': 'Gooey',
#              'track_uri': 'spotify:track:5b9iBVhfYxDF4JJcHrNIx5'},
#             {'album_name': 'Birds '
#                            'In '
#                            'The '
#                            'Trap '
#                            'Sing '
#                            'McKnight',
#              'album_uri': 'spotify:album:42WVQWuf1teDysXiOupIZt',
#              'artist_name': 'Travis '
#                             'Scott',
#              'artist_uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY',
#              'duration_ms': 243836,
#              'pos': 3,
#              'track_name': 'goosebumps',
#              'track_uri': 'spotify:track:6gBFPUFcJLzWGx4lenP6h2'},
#             {'album_name': 'Candyman',
#              'album_uri': 'spotify:album:1VpoLsTerjvNzDNGWP6bmq',
#              'artist_name': 'Zedd',
#              'artist_uri': 'spotify:artist:2qxJFvFYMEDqd7ui6kSAcq',
#              'duration_ms': 178920,
#              'pos': 4,
#              'track_name': 'Candyman',
#              'track_uri': 'spotify:track:0NWQTyapmz4GuDTSN9xTB7'},
#             {'album_name': 'Bad '
#                            '25th '
#                            'Anniversary',
#              'album_uri': 'spotify:album:24TAupSNVWSAHL0R7n71vm',
#              'artist_name': 'Michael '
#                             'Jackson',
#              'artist_uri': 'spotify:artist:3fMbdgg4jU18AjLCKBhRSm',
#              'duration_ms': 318680,
#              'pos': 5,
#              'track_name': 'Man '
#                            'in '
#                            'the '
#                            'Mirror '
#                            '- '
#                            '2012 '
#                            'Remaster',
#              'track_uri': 'spotify:track:1kiNatIrwDusOZfR29W0LJ'},
#             {'album_name': 'For '
#                            'Emma, '
#                            'Forever '
#                            'Ago',
#              'album_uri': 'spotify:album:10HuTnFqkhym6gXmIDxBsm',
#              'artist_name': 'Bon '
#                             'Iver',
#              'artist_uri': 'spotify:artist:4LEiUm1SRbFMgfqnQTwUbQ',
#              'duration_ms': 232426,
#              'pos': 6,
#              'track_name': 'Skinny '
#                            'Love',
#              'track_uri': 'spotify:track:3ZMv9EzGoteNi5Qnx0KpEO'},
#             {'album_name': 'A '
#                            'Pentatonix '
#                            'Christmas',
#              'album_uri': 'spotify:album:3oXvzShPN8iY2P1UYl3WVJ',
#              'artist_name': 'Pentatonix',
#              'artist_uri': 'spotify:artist:26AHtbjWKiwYzsoGoUZq53',
#              'duration_ms': 268960,
#              'pos': 7,
#              'track_name': 'Hallelujah',
#              'track_uri': 'spotify:track:550rQQCGkrTzvp4SfpOPzx'},
#             {'album_name': 'The '
#                            'Traveller',
#              'album_uri': 'spotify:album:1W7jVZLyOKOpmkzqBNXypn',
#              'artist_name': 'Baaba '
#                             'Maal',
#              'artist_uri': 'spotify:artist:49z6oAiD2RpyUf5yLJs7Nf',
#              'duration_ms': 266930,
#              'pos': 8,
#              'track_name': 'There '
#                            'Will '
#                            'Be '
#                            'Time',
#              'track_uri': 'spotify:track:7Ddh0jbUW6q0O1Mt7IYEPX'},
#             {'album_name': 'The '
#                            'Diary '
#                            'Of '
#                            'Alicia '
#                            'Keys',
#              'album_uri': 'spotify:album:6TqRKHLjDu5QZuC8u5Woij',
#              'artist_name': 'Alicia '
#                             'Keys',
#              'artist_uri': 'spotify:artist:3DiDSECUqqY1AuBP8qtaIa',
#              'duration_ms': 228706,
#              'pos': 9,
#              'track_name': 'If '
#                            'I '
#                            "Ain't "
#                            'Got '
#                            'You',
#              'track_uri': 'spotify:track:3XVBdLihbNbxUwZosxcGuJ'},
#             {'album_name': 'The '
#                            'Dutchess',
#              'album_uri': 'spotify:album:0jwuTvP3hp2jFY08VLgvnD',
#              'artist_name': 'Fergie',
#              'artist_uri': 'spotify:artist:3r17AfJCCUqC9Lf0OAc73G',
#              'duration_ms': 268120,
#              'pos': 10,
#              'track_name': 'Big '
#                            'Girls '
#                            "Don't "
#                            'Cry '
#                            '(Personal)',
#              'track_uri': 'spotify:track:3Q4WeJmzxuDpzMu9QjQqbM'},
#             {'album_name': 'Room '
#                            'For '
#                            'Squares',
#              'album_uri': 'spotify:album:3yHOaiXecTJVUdn7mApZ48',
#              'artist_name': 'John '
#                             'Mayer',
#              'artist_uri': 'spotify:artist:0hEurMDQu99nJRq8pTxO14',
#              'duration_ms': 249626,
#              'pos': 11,
#              'track_name': 'Your '
#                            'Body '
#                            'Is '
#                            'a '
#                            'Wonderland',
#              'track_uri': 'spotify:track:7vFv0yFGMJW3qVXbAd9BK9'},
#             {'album_name': 'Double '
#                            'Wide',
#              'album_uri': 'spotify:album:0Fc7RtFLwtDz5pD622l7kQ',
#              'artist_name': 'Uncle '
#                             'Kracker',
#              'artist_uri': 'spotify:artist:2DnqqkzzDKm3vAoyHtn8So',
#              'duration_ms': 218439,
#              'pos': 12,
#              'track_name': 'Follow '
#                            'Me',
#              'track_uri': 'spotify:track:4KoecuyOpZaNFZ0UqVsllc'},
#             {'album_name': 'The '
#                            'Bodyguard '
#                            '- '
#                            'Original '
#                            'Soundtrack '
#                            'Album',
#              'album_uri': 'spotify:album:7JVJlkNNobS0GSoy4tCS96',
#              'artist_name': 'Whitney '
#                             'Houston',
#              'artist_uri': 'spotify:artist:6XpaIBNiVzIetEPCWDvAFP',
#              'duration_ms': 271093,
#              'pos': 13,
#              'track_name': 'I '
#                            'Will '
#                            'Always '
#                            'Love '
#                            'You',
#              'track_uri': 'spotify:track:4eHbdreAnSOrDDsFfc4Fpm'},
#             {'album_name': 'The '
#                            'Temptations '
#                            'Sing '
#                            'Smokey',
#              'album_uri': 'spotify:album:5H2rffw6MNKGWVKBNWNA4S',
#              'artist_name': 'The '
#                             'Temptations',
#              'artist_uri': 'spotify:artist:3RwQ26hR2tJtA8F9p2n7jG',
#              'duration_ms': 165000,
#              'pos': 14,
#              'track_name': 'My '
#                            'Girl',
#              'track_uri': 'spotify:track:6RrXd9Hph4hYR4bf3dbM6H'},
#             {'album_name': 'Back '
#                            'To '
#                            'Black',
#              'album_uri': 'spotify:album:6GJCGWfI95aeRsdtVB52vc',
#              'artist_name': 'Amy '
#                             'Winehouse',
#              'artist_uri': 'spotify:artist:6Q192DXotxtaysaqNPy5yR',
#              'duration_ms': 213760,
#              'pos': 15,
#              'track_name': 'Rehab',
#              'track_uri': 'spotify:track:4osg3vT6sXv6wNxm9Z6ucQ'},
#             {'album_name': 'Seven '
#                            '+ '
#                            'Mary',
#              'album_uri': 'spotify:album:4lGNpgFI67TUq5BMfnPe3Z',
#              'artist_name': 'Rainbow '
#                             'Kitten '
#                             'Surprise',
#              'artist_uri': 'spotify:artist:4hz8tIajF2INpgM0qzPJz2',
#              'duration_ms': 210417,
#              'pos': 16,
#              'track_name': 'Mr. '
#                            'Redundant',
#              'track_uri': 'spotify:track:2yPiN3T8Z0YE4uovhPyaB3'},
#             {'album_name': 'RKS',
#              'album_uri': 'spotify:album:2aaWMtuGxw17AZpKhZGdXQ',
#              'artist_name': 'Rainbow '
#                             'Kitten '
#                             'Surprise',
#              'artist_uri': 'spotify:artist:4hz8tIajF2INpgM0qzPJz2',
#              'duration_ms': 206626,
#              'pos': 17,
#              'track_name': "All's "
#                            'Well '
#                            'That '
#                            'Ends',
#              'track_uri': 'spotify:track:37ZvpHeZKazqOnLfAGm9nb'},
#             {'album_name': 'American '
#                            'Idiot',
#              'album_uri': 'spotify:album:5dN7F9DV0Qg1XRdIgW8rke',
#              'artist_name': 'Green '
#                             'Day',
#              'artist_uri': 'spotify:artist:7oPftvlwr6VrsViSDV7fJY',
#              'duration_ms': 548253,
#              'pos': 18,
#              'track_name': 'Jesus '
#                            'Of '
#                            'Suburbia',
#              'track_uri': 'spotify:track:58KPPL1AdLHMvR2O2PZejr'},
#             {'album_name': 'Louder '
#                            'Than '
#                            'Bombs',
#              'album_uri': 'spotify:album:45StnugV9WQMQwk4rRoTy8',
#              'artist_name': 'The '
#                             'Smiths',
#              'artist_uri': 'spotify:artist:3yY2gUcIsjMr8hjo51PoJ8',
#              'duration_ms': 253560,
#              'pos': 19,
#              'track_name': 'Asleep '
#                            '- '
#                            '2011 '
#                            'Remastered '
#                            'Version',
#              'track_uri': 'spotify:track:7LZgdL0MxiElfaKZbuuE4l'},
#             {'album_name': 'The '
#                            'Heist',
#              'album_uri': 'spotify:album:76FXHQhTuT4QMIxfL09gX8',
#              'artist_name': 'Macklemore '
#                             '& '
#                             'Ryan '
#                             'Lewis',
#              'artist_uri': 'spotify:artist:5BcAKTbp20cv7tC5VqPFoC',
#              'duration_ms': 298640,
#              'pos': 20,
#              'track_name': 'Wing$',
#              'track_uri': 'spotify:track:5n5uyFpfopa4mNdSN0gTaH'},
#             {'album_name': 'Falling '
#                            'Into '
#                            'You',
#              'album_uri': 'spotify:album:55UPmpHLvZKGgTPUD1woES',
#              'artist_name': 'Céline '
#                             'Dion',
#              'artist_uri': 'spotify:artist:4S9EykWXhStSc15wEx8QFK',
#              'duration_ms': 456866,
#              'pos': 21,
#              'track_name': "It's "
#                            'All '
#                            'Coming '
#                            'Back '
#                            'to '
#                            'Me '
#                            'Now',
#              'track_uri': 'spotify:track:2JRicL2f8tJl9TiQlH7vbJ'},
#             {'album_name': '21st '
#                            'Century '
#                            'Breakdown',
#              'album_uri': 'spotify:album:1AHZd3C3S8m8fFrhFxyk79',
#              'artist_name': 'Green '
#                             'Day',
#              'artist_uri': 'spotify:artist:7oPftvlwr6VrsViSDV7fJY',
#              'duration_ms': 190986,
#              'pos': 22,
#              'track_name': 'Know '
#                            'Your '
#                            'Enemy',
#              'track_uri': 'spotify:track:5qtwzv99vOr5UTwnTixn7j'},
#             {'album_name': 'Martina',
#              'album_uri': 'spotify:album:3xtQSAQgeAV6TcvzyF4iDd',
#              'artist_name': 'Martina '
#                             'McBride',
#              'artist_uri': 'spotify:artist:3P33qFNGBVXl86yQYWspFj',
#              'duration_ms': 243160,
#              'pos': 23,
#              'track_name': 'This '
#                            "One's "
#                            'for '
#                            'the '
#                            'Girls',
#              'track_uri': 'spotify:track:01CnYyPXMFRzOFVQBU8WMb'},
#             {'album_name': 'blink-182',
#              'album_uri': 'spotify:album:6DMUAqxiFfLdqXv0vqcrQA',
#              'artist_name': 'blink-182',
#              'artist_uri': 'spotify:artist:6FBDaR13swtiWwGhX1WQsP',
#              'duration_ms': 227240,
#              'pos': 24,
#              'track_name': 'I '
#                            'Miss '
#                            'You',
#              'track_uri': 'spotify:track:1oTo3ijRbaDAtrjJrGAPSw'},
#             {'album_name': 'Heartbreaker',
#              'album_uri': 'spotify:album:7hmZCaBzp6mVrelxW6Ckrn',
#              'artist_name': 'Ryan '
#                             'Adams',
#              'artist_uri': 'spotify:artist:2qc41rNTtdLK0tV3mJn2Pm',
#              'duration_ms': 173000,
#              'pos': 25,
#              'track_name': 'Shakedown '
#                            'on '
#                            '9th '
#                            'Street',
#              'track_uri': 'spotify:track:7mkiPWtd5pGqEXGvDaXWJC'},
#             {'album_name': 'Let '
#                            'It '
#                            'Be',
#              'album_uri': 'spotify:album:2pCqZLeavM2BMovJXsJEIV',
#              'artist_name': 'The '
#                             'Beatles',
#              'artist_uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2',
#              'duration_ms': 243026,
#              'pos': 26,
#              'track_name': 'Let '
#                            'It '
#                            'Be '
#                            '- '
#                            'Remastered',
#              'track_uri': 'spotify:track:5V1AHQugSTASVez5ffJtFo'},
#             {'album_name': 'The '
#                            'Head '
#                            'And '
#                            'The '
#                            'Heart',
#              'album_uri': 'spotify:album:4JKVVz1tD8PYKoXIZ7ZEJy',
#              'artist_name': 'The '
#                             'Head '
#                             'and '
#                             'the '
#                             'Heart',
#              'artist_uri': 'spotify:artist:0n94vC3S9c3mb2HyNAOcjg',
#              'duration_ms': 190293,
#              'pos': 27,
#              'track_name': 'Sounds '
#                            'Like '
#                            'Hallelujah',
#              'track_uri': 'spotify:track:0noXQp6SyrsYTpnMAVhi6q'},
#             {'album_name': 'Pet '
#                            'Sounds',
#              'album_uri': 'spotify:album:6GphKx2QAPRoVGWE9D7ou8',
#              'artist_name': 'The '
#                             'Beach '
#                             'Boys',
#              'artist_uri': 'spotify:artist:3oDbviiivRWhXwIE8hxkVV',
#              'duration_ms': 153240,
#              'pos': 28,
#              'track_name': "Wouldn't "
#                            'It '
#                            'Be '
#                            'Nice '
#                            '- '
#                            '2000 '
#                            '- '
#                            'Remaster',
#              'track_uri': 'spotify:track:2Gy7qnDwt8Z3MNxqat4CsK'},
#             {'album_name': 'For '
#                            'Emma, '
#                            'Forever '
#                            'Ago',
#              'album_uri': 'spotify:album:10HuTnFqkhym6gXmIDxBsm',
#              'artist_name': 'Bon '
#                             'Iver',
#              'artist_uri': 'spotify:artist:4LEiUm1SRbFMgfqnQTwUbQ',
#              'duration_ms': 322040,
#              'pos': 29,
#              'track_name': 'The '
#                            'Wolves '
#                            '(Act '
#                            'I '
#                            'and '
#                            'II)',
#              'track_uri': 'spotify:track:0Tps1iVuFudov2alVP3bUF'},
#             {'album_name': 'Seven '
#                            '+ '
#                            'Mary',
#              'album_uri': 'spotify:album:4lGNpgFI67TUq5BMfnPe3Z',
#              'artist_name': 'Rainbow '
#                             'Kitten '
#                             'Surprise',
#              'artist_uri': 'spotify:artist:4hz8tIajF2INpgM0qzPJz2',
#              'duration_ms': 188280,
#              'pos': 30,
#              'track_name': 'Devil '
#                            'Like '
#                            'Me',
#              'track_uri': 'spotify:track:0HsGh7cboYz6cVMIyFrQ8j'},
#             {'album_name': 'RKS',
#              'album_uri': 'spotify:album:2aaWMtuGxw17AZpKhZGdXQ',
#              'artist_name': 'Rainbow '
#                             'Kitten '
#                             'Surprise',
#              'artist_uri': 'spotify:artist:4hz8tIajF2INpgM0qzPJz2',
#              'duration_ms': 231266,
#              'pos': 31,
#              'track_name': 'The '
#                            'Comedown',
#              'track_uri': 'spotify:track:4FMRToryd5E6dwGPh0hA26'},
#             {'album_name': 'Run '
#                            'River '
#                            'North',
#              'album_uri': 'spotify:album:2RyIQJb2ruv5nJ55EFEwyu',
#              'artist_name': 'Run '
#                             'River '
#                             'North',
#              'artist_uri': 'spotify:artist:0INDB6Snts5NDbzh8jC3lk',
#              'duration_ms': 243960,
#              'pos': 32,
#              'track_name': 'Growing '
#                            'Up',
#              'track_uri': 'spotify:track:0VaOlp5rnOdvU664eQXq5d'},
#             {'album_name': "Can't "
#                            'Bring '
#                            'This '
#                            'Down',
#              'album_uri': 'spotify:album:7JFq8A2oMFQiZT2m1xx9P3',
#              'artist_name': 'Bridgit '
#                             'Mendler',
#              'artist_uri': 'spotify:artist:4VhL8KLjVso4vLfOLVViTb',
#              'duration_ms': 216233,
#              'pos': 33,
#              'track_name': "Can't "
#                            'Bring '
#                            'This '
#                            'Down',
#              'track_uri': 'spotify:track:3SMrDTwimapSxKnfMQyRj6'},
#             {'album_name': 'Gone '
#                            'Now',
#              'album_uri': 'spotify:album:10HKbC9lKDHGQvndGck6XJ',
#              'artist_name': 'Bleachers',
#              'artist_uri': 'spotify:artist:2eam0iDomRHGBypaDQLwWI',
#              'duration_ms': 235253,
#              'pos': 34,
#              'track_name': 'Everybody '
#                            'Lost '
#                            'Somebody',
#              'track_uri': 'spotify:track:4JkOsslKrWDYYb5dcft9AH'},
#             {'album_name': 'ANTI',
#              'album_uri': 'spotify:album:3Q149ZH46Z0f3oDR7vlDYV',
#              'artist_name': 'Rihanna',
#              'artist_uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H',
#              'duration_ms': 224000,
#              'pos': 35,
#              'track_name': 'Love '
#                            'On '
#                            'The '
#                            'Brain',
#              'track_uri': 'spotify:track:2aksifNn5ph8igDOkPBA02'},
#             {'album_name': 'Final '
#                            'Song',
#              'album_uri': 'spotify:album:2gcqSlK5xTxcpuLZ1iik3Z',
#              'artist_name': 'MØ',
#              'artist_uri': 'spotify:artist:0bdfiayQAKewqEvaU6rXCv',
#              'duration_ms': 235826,
#              'pos': 36,
#              'track_name': 'Final '
#                            'Song',
#              'track_uri': 'spotify:track:4qqArAiTPueDxIp7cf87h7'},
#             {'album_name': 'The '
#                            'Head '
#                            'And '
#                            'The '
#                            'Heart',
#              'album_uri': 'spotify:album:4JKVVz1tD8PYKoXIZ7ZEJy',
#              'artist_name': 'The '
#                             'Head '
#                             'and '
#                             'the '
#                             'Heart',
#              'artist_uri': 'spotify:artist:0n94vC3S9c3mb2HyNAOcjg',
#              'duration_ms': 340386,
#              'pos': 37,
#              'track_name': 'Heaven '
#                            'Go '
#                            'Easy '
#                            'On '
#                            'Me',
#              'track_uri': 'spotify:track:2JI9Ic2ZugHh8EQ2U6zV8G'},
#             {'album_name': 'Surf',
#              'album_uri': 'spotify:album:3eM1KTKmpqrQOvuvYY42cr',
#              'artist_name': 'Donnie '
#                             'Trumpet '
#                             '& '
#                             'The '
#                             'Social '
#                             'Experiment',
#              'artist_uri': 'spotify:artist:0ojcq9LJQWMawQdFDw3M0L',
#              'duration_ms': 226013,
#              'pos': 38,
#              'track_name': 'Sunday '
#                            'Candy',
#              'track_uri': 'spotify:track:6fTdcGsjxlAD9PSkoPaLMX'},
#             {'album_name': 'Ripcord',
#              'album_uri': 'spotify:album:1r7ABqzNXQnUPAH3ZjrHMn',
#              'artist_name': 'Keith '
#                             'Urban',
#              'artist_uri': 'spotify:artist:0u2FHSq3ln94y5Q57xazwf',
#              'duration_ms': 184040,
#              'pos': 39,
#              'track_name': 'The '
#                            'Fighter',
#              'track_uri': 'spotify:track:7EAFj7eJcMF5koWSRJVZcL'},
#             {'album_name': 'Body '
#                            'Like '
#                            'A '
#                            'Back '
#                            'Road',
#              'album_uri': 'spotify:album:2N7kidh1wA9EoLdf16QWrz',
#              'artist_name': 'Sam '
#                             'Hunt',
#              'artist_uri': 'spotify:artist:2kucQ9jQwuD8jWdtR9Ef38',
#              'duration_ms': 165386,
#              'pos': 40,
#              'track_name': 'Body '
#                            'Like '
#                            'A '
#                            'Back '
#                            'Road',
#              'track_uri': 'spotify:track:7mldq42yDuxiUNn08nvzHO'},
#             {'album_name': 'H '
#                            'A '
#                            'R '
#                            'D '
#                            'L '
#                            'O '
#                            'V '
#                            'E',
#              'album_uri': 'spotify:album:0DjJIQPOsxd5OiUoVskRBH',
#              'artist_name': 'NEEDTOBREATHE',
#              'artist_uri': 'spotify:artist:610EjgFatGvVPtib97jQ8G',
#              'duration_ms': 56360,
#              'pos': 41,
#              'track_name': 'MOUNTAIN, '
#                            'Pt '
#                            '1',
#              'track_uri': 'spotify:track:5B2s8mPL2jvdRVwCPAqy3Z'},
#             {'album_name': 'H '
#                            'A '
#                            'R '
#                            'D '
#                            'L '
#                            'O '
#                            'V '
#                            'E',
#              'album_uri': 'spotify:album:0DjJIQPOsxd5OiUoVskRBH',
#              'artist_name': 'NEEDTOBREATHE',
#              'artist_uri': 'spotify:artist:610EjgFatGvVPtib97jQ8G',
#              'duration_ms': 214626,
#              'pos': 42,
#              'track_name': 'HARD '
#                            'LOVE',
#              'track_uri': 'spotify:track:0xcFH3973DZauDkGnNjMgm'},
#             {'album_name': 'H '
#                            'A '
#                            'R '
#                            'D '
#                            'L '
#                            'O '
#                            'V '
#                            'E',
#              'album_uri': 'spotify:album:0DjJIQPOsxd5OiUoVskRBH',
#              'artist_name': 'NEEDTOBREATHE',
#              'artist_uri': 'spotify:artist:610EjgFatGvVPtib97jQ8G',
#              'duration_ms': 192146,
#              'pos': 43,
#              'track_name': 'MONEY '
#                            '& '
#                            'FAME',
#              'track_uri': 'spotify:track:4jtJZ9mep9Cdh8RGl5vw0g'},
#             {'album_name': 'H '
#                            'A '
#                            'R '
#                            'D '
#                            'L '
#                            'O '
#                            'V '
#                            'E',
#              'album_uri': 'spotify:album:0DjJIQPOsxd5OiUoVskRBH',
#              'artist_name': 'NEEDTOBREATHE',
#              'artist_uri': 'spotify:artist:610EjgFatGvVPtib97jQ8G',
#              'duration_ms': 165240,
#              'pos': 44,
#              'track_name': 'NO '
#                            'EXCUSES',
#              'track_uri': 'spotify:track:3o1OKJvEN5nAnhnHhUnbCx'},
#             {'album_name': 'H '
#                            'A '
#                            'R '
#                            'D '
#                            'L '
#                            'O '
#                            'V '
#                            'E',
#              'album_uri': 'spotify:album:0DjJIQPOsxd5OiUoVskRBH',
#              'artist_name': 'NEEDTOBREATHE',
#              'artist_uri': 'spotify:artist:610EjgFatGvVPtib97jQ8G',
#              'duration_ms': 162480,
#              'pos': 45,
#              'track_name': 'WHEN '
#                            'I '
#                            'SING',
#              'track_uri': 'spotify:track:4ZP6l1gBTMuGterGX45ajy'},
#             {'album_name': 'H '
#                            'A '
#                            'R '
#                            'D '
#                            'L '
#                            'O '
#                            'V '
#                            'E',
#              'album_uri': 'spotify:album:0DjJIQPOsxd5OiUoVskRBH',
#              'artist_name': 'NEEDTOBREATHE',
#              'artist_uri': 'spotify:artist:610EjgFatGvVPtib97jQ8G',
#              'duration_ms': 205773,
#              'pos': 46,
#              'track_name': 'HAPPINESS',
#              'track_uri': 'spotify:track:7aag0fFgE9K1Gj8lJwQaGI'},
#             {'album_name': 'H '
#                            'A '
#                            'R '
#                            'D '
#                            'L '
#                            'O '
#                            'V '
#                            'E',
#              'album_uri': 'spotify:album:0DjJIQPOsxd5OiUoVskRBH',
#              'artist_name': 'NEEDTOBREATHE',
#              'artist_uri': 'spotify:artist:610EjgFatGvVPtib97jQ8G',
#              'duration_ms': 175680,
#              'pos': 47,
#              'track_name': 'GREAT '
#                            'NIGHT '
#                            '(feat. '
#                            'Shovels '
#                            '& '
#                            'Rope)',
#              'track_uri': 'spotify:track:41cxe6eOzzQS6odQk6fNdp'},
#             {'album_name': 'H '
#                            'A '
#                            'R '
#                            'D '
#                            'L '
#                            'O '
#                            'V '
#                            'E',
#              'album_uri': 'spotify:album:0DjJIQPOsxd5OiUoVskRBH',
#              'artist_name': 'NEEDTOBREATHE',
#              'artist_uri': 'spotify:artist:610EjgFatGvVPtib97jQ8G',
#              'duration_ms': 215306,
#              'pos': 48,
#              'track_name': 'BE '
#                            'HERE '
#                            'LONG',
#              'track_uri': 'spotify:track:6aXKP2TWEkgruJvRujGMKG'},
#             {'album_name': 'H '
#                            'A '
#                            'R '
#                            'D '
#                            'L '
#                            'O '
#                            'V '
#                            'E',
#              'album_uri': 'spotify:album:0DjJIQPOsxd5OiUoVskRBH',
#              'artist_name': 'NEEDTOBREATHE',
#              'artist_uri': 'spotify:artist:610EjgFatGvVPtib97jQ8G',
#              'duration_ms': 176933,
#              'pos': 49,
#              'track_name': "DON'T "
#                            'BRING '
#                            'THAT '
#                            'TROUBLE',
#              'track_uri': 'spotify:track:6WaIDdOdfmWdvXvUyBMq7F'},
#             {'album_name': 'H '
#                            'A '
#                            'R '
#                            'D '
#                            'L '
#                            'O '
#                            'V '
#                            'E',
#              'album_uri': 'spotify:album:0DjJIQPOsxd5OiUoVskRBH',
#              'artist_name': 'NEEDTOBREATHE',
#              'artist_uri': 'spotify:artist:610EjgFatGvVPtib97jQ8G',
#              'duration_ms': 200120,
#              'pos': 50,
#              'track_name': "LET'S "
#                            'STAY '
#                            'HOME '
#                            'TONIGHT',
#              'track_uri': 'spotify:track:1kiylxwnw8R8rJoCDtubWM'},
#             {'album_name': 'H '
#                            'A '
#                            'R '
#                            'D '
#                            'L '
#                            'O '
#                            'V '
#                            'E',
#              'album_uri': 'spotify:album:0DjJIQPOsxd5OiUoVskRBH',
#              'artist_name': 'NEEDTOBREATHE',
#              'artist_uri': 'spotify:artist:610EjgFatGvVPtib97jQ8G',
#              'duration_ms': 243800,
#              'pos': 51,
#              'track_name': 'TESTIFY',
#              'track_uri': 'spotify:track:5OpjJ9qy54D3PzQJ1s4Q9X'},
#             {'album_name': 'H '
#                            'A '
#                            'R '
#                            'D '
#                            'L '
#                            'O '
#                            'V '
#                            'E',
#              'album_uri': 'spotify:album:0DjJIQPOsxd5OiUoVskRBH',
#              'artist_name': 'NEEDTOBREATHE',
#              'artist_uri': 'spotify:artist:610EjgFatGvVPtib97jQ8G',
#              'duration_ms': 411080,
#              'pos': 52,
#              'track_name': 'CLEAR',
#              'track_uri': 'spotify:track:3fq09awXzr1ghRFhvOMZsi'},
#             {'album_name': 'Broad '
#                            'Shoulders',
#              'album_uri': 'spotify:album:61KTKfjFX7exj2Od31ulYA',
#              'artist_name': 'Taylor '
#                             'Bennett',
#              'artist_uri': 'spotify:artist:6CqjoQyGZlnhnq5gAUz92c',
#              'duration_ms': 227263,
#              'pos': 53,
#              'track_name': 'Broad '
#                            'Shoulders '
#                            '(feat. '
#                            'Chance '
#                            'the '
#                            'Rapper)',
#              'track_uri': 'spotify:track:6m3ZXs465Rt4Tc1iiLktXL'},
#             {'album_name': 'Playlist: '
#                            'The '
#                            'Very '
#                            'Best '
#                            'Of '
#                            'Five '
#                            'For '
#                            'Fighting',
#              'album_uri': 'spotify:album:1QBU2iq38q3Y8PWlBhRFzk',
#              'artist_name': 'Five '
#                             'For '
#                             'Fighting',
#              'artist_uri': 'spotify:artist:7FgMLbnZVrEnir95O0YujA',
#              'duration_ms': 222160,
#              'pos': 54,
#              'track_name': 'Superman '
#                            "(It's "
#                            'Not '
#                            'Easy)',
#              'track_uri': 'spotify:track:3FvCy00Wz75HmhlXPMmnOx'},
#             {'album_name': 'Yourself '
#                            'Or '
#                            'Someone '
#                            'Like '
#                            'You',
#              'album_uri': 'spotify:album:4vUXTcKz7tXxrNl84meN6i',
#              'artist_name': 'Matchbox '
#                             'Twenty',
#              'artist_uri': 'spotify:artist:3Ngh2zDBRPEriyxQDAMKd1',
#              'duration_ms': 225946,
#              'pos': 55,
#              'track_name': '3AM',
#              'track_uri': 'spotify:track:5vYA1mW9g2Coh1HUFUSmlb'},
#             {'album_name': 'Train',
#              'album_uri': 'spotify:album:01aoYWjhjshlHf5vJNYb03',
#              'artist_name': 'Train',
#              'artist_uri': 'spotify:artist:3FUY2gzHeIiaesXtOAdB7A',
#              'duration_ms': 239933,
#              'pos': 56,
#              'track_name': 'Meet '
#                            'Virginia',
#              'track_uri': 'spotify:track:4ocbH5ZJqajZIpUrqRUoue'},
#             {'album_name': '4',
#              'album_uri': 'spotify:album:1gIC63gC3B7o7FfpPACZQJ',
#              'artist_name': 'Beyoncé',
#              'artist_uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m',
#              'duration_ms': 212146,
#              'pos': 57,
#              'track_name': 'Countdown',
#              'track_uri': 'spotify:track:3axkNosdVQLZiq1HakuGhc'},
#             {'album_name': 'Songs '
#                            'For '
#                            'Sunset '
#                            'Lovers',
#              'album_uri': 'spotify:album:1STfmRBX2iFpZkDMY6mKqT',
#              'artist_name': 'Charles '
#                             'Givings',
#              'artist_uri': 'spotify:artist:7sQg9yOabzv2g23MyIMN7M',
#              'duration_ms': 266320,
#              'pos': 58,
#              'track_name': 'Easy '
#                            '(LIke '
#                            'Sunday '
#                            'Morning)',
#              'track_uri': 'spotify:track:5lnLxpRxCDlqedyWgkBLOh'},
#             {'album_name': 'Feeling '
#                            'Strangely '
#                            'Fine',
#              'album_uri': 'spotify:album:7c6A82iJXXYlZq2huhkU3E',
#              'artist_name': 'Semisonic',
#              'artist_uri': 'spotify:artist:1TqQi97nqeiuOJrIFv5Sw0',
#              'duration_ms': 273533,
#              'pos': 59,
#              'track_name': 'Closing '
#                            'Time',
#              'track_uri': 'spotify:track:4EnkwZd0UJAuHpNMMemQaA'},
#             {'album_name': 'Face '
#                            'Value '
#                            '(Deluxe '
#                            'Editon)',
#              'album_uri': 'spotify:album:1cM3r0WQZWNkCpEbmFjLln',
#              'artist_name': 'Phil '
#                             'Collins',
#              'artist_uri': 'spotify:artist:4lxfqrEsLX6N1N4OCSkILp',
#              'duration_ms': 336453,
#              'pos': 60,
#              'track_name': 'In '
#                            'The '
#                            'Air '
#                            'Tonight '
#                            '- '
#                            '2015 '
#                            'Remastered',
#              'track_uri': 'spotify:track:18AXbzPzBS8Y3AkgSxzJPb'},
#             {'album_name': 'Flicker',
#              'album_uri': 'spotify:album:3QLB5s0MY7ERTwh4GpNMkf',
#              'artist_name': 'Niall '
#                             'Horan',
#              'artist_uri': 'spotify:artist:1Hsdzj7Dlq2I7tHP7501T4',
#              'duration_ms': 188174,
#              'pos': 61,
#              'track_name': 'Slow '
#                            'Hands',
#              'track_uri': 'spotify:track:38yBBH2jacvDxrznF7h08J'},
#             {'album_name': 'The '
#                            'Marshall '
#                            'Mathers '
#                            'LP2',
#              'album_uri': 'spotify:album:3qGeRY1wt4rrLIt1YuSwHR',
#              'artist_name': 'Eminem',
#              'artist_uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR',
#              'duration_ms': 343032,
#              'pos': 62,
#              'track_name': 'Headlights',
#              'track_uri': 'spotify:track:14WB9RMGcLvEKWNgPP22fV'}]}

# %%
# Building relevant data structures
tracks_per_user, users_per_track, artists_per_user = build_relevant_ds(data)
# Out:
# Preprocessing started...

# %%
tracks_per_user[7002]
